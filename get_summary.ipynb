# %%
from mlp_ensemble import get_model_summary, process_csv
# Out:
# 2024-11-20 17:17:26.961783: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-20 17:17:26.973196: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-20 17:17:26.988094: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-20 17:17:26.992403: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-20 17:17:27.002327: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df_summary = get_model_summary(base_folder = 'mlp_ensemble_englacial_5')
# Out:
# Processing folder: 4608738747481363481
# Processing folder: -2521063934326924105
# Processing folder: -8986769842886357244
# Processing folder: 8726941782708825324
# Processing folder: -3041433977190789785
# Processing folder: -6526983590773762683
# Processing folder: -8068565619782484689
# Processing folder: 6990242843191021224
# Processing folder: 5793560991531227906
# Processing folder: 5547991080731137248
# Processing folder: 7640605556438757992
# Processing folder: 170944646488101895
# Processing folder: -7148532254639451841
# Summary saved as summary_20241120_171751.csv

# %%
df_summary
# Out:
#             folder_name                                      input_columns  \
# 0   4608738747481363481               [s, h, mag_h, mag_s, driving_stress]
# 1  -2521063934326924105            [s, h, mag_h, mag_s, snow_accumulation]
# 2  -8986769842886357244  [s, h, mag_h, mag_s, driving_stress, snow_accu...
# 3   8726941782708825324  [s, b, h, mag_h, mag_s, mag_b, driving_stress,...
# 4  -3041433977190789785                               [b, mag_b, heatflux]
# 5  -6526983590773762683                    [b, mag_b, gravity_disturbance]
# 6  -8068565619782484689          [b, mag_b, heatflux, gravity_disturbance]
# 7   6990242843191021224                                             [s, h]
# 8   5793560991531227906                                     [mag_h, mag_s]
# 9   5547991080731137248                    [heatflux, gravity_disturbance]
# 10  7640605556438757992             [s, h, mag_h, mag_s, surface_air_temp]
# 11   170944646488101895                               [s, h, mag_h, mag_s]
# 12 -7148532254639451841  [driving_stress, snow_accumulation, surface_ai...
#
#      r2_mean    r2_std  r2_median  r2_adjusted_mean  r2_adjusted_std  \
# 0   0.245928  0.446205   0.470258          0.245883         0.446232
# 1   0.151279  0.416396   0.317301          0.151229         0.416420
# 2   0.624542  0.332104   0.747881          0.624512         0.332131
# 3   0.789200  0.200107   0.902926          0.789173         0.200133
# 4   0.342862  0.082081   0.333602          0.342839         0.082084
# 5   0.112092  0.172557   0.143466          0.112060         0.172563
# 6   0.896987  0.031023   0.892089          0.896982         0.031025
# 7   0.203836  0.099747   0.226476          0.203817         0.099750
# 8  -5.550778  1.396530  -5.157665         -5.550931         1.396563
# 9   0.019991  0.072888   0.038460          0.019968         0.072889
# 10  0.409563  0.356822   0.304437          0.409528         0.356843
# 11  0.056138  0.335454   0.012720          0.056093         0.335469
# 12 -0.870442  0.171422  -0.879069         -0.870508         0.171428
#
#     r2_adjusted_median  mse_mean   mse_std  mse_median  number_of_models
# 0             0.470227  0.000044  0.000011    0.000039                10
# 1             0.317261  0.000043  0.000009    0.000042                10
# 2             0.747860  0.000025  0.000014    0.000020                10
# 3             0.902914  0.000015  0.000012    0.000009                10
# 4             0.333578  0.000043  0.000004    0.000042                 8
# 5             0.143436  0.000049  0.000005    0.000049                10
# 6             0.892084  0.000009  0.000002    0.000009                10
# 7             0.226458  0.000046  0.000006    0.000044                10
# 8            -5.157810  0.000094  0.000004    0.000092                10
# 9             0.038437  0.000051  0.000004    0.000050                10
# 10            0.304397  0.000035  0.000016    0.000042                10
# 11            0.012674  0.000049  0.000011    0.000051                10
# 12           -0.879135  0.000066  0.000005    0.000065                10

# %%
duplicates = df_summary[df_summary['input_columns'].duplicated(keep=False)]

# Display duplicates
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [folder_name, input_columns, r2_mean, r2_std, r2_median, r2_adjusted_mean, r2_adjusted_std, r2_adjusted_median, mse_mean, mse_std, mse_median, number_of_models]
# Index: []

# %%
import pandas
# Set max_colwidth to None to display the full content of the cells
pandas.set_option('display.max_colwidth', None)

# Display the DataFrame again
print(df_summary['input_columns'].to_string())
# Out:
# 0                                                                                   [s, h, mag_h, mag_s, driving_stress]
# 1                                                                                [s, h, mag_h, mag_s, snow_accumulation]
# 2                                              [s, h, mag_h, mag_s, driving_stress, snow_accumulation, surface_air_temp]
# 3     [s, b, h, mag_h, mag_s, mag_b, driving_stress, heatflux, snow_accumulation, surface_air_temp, gravity_disturbance]
# 4                                                                                                   [b, mag_b, heatflux]
# 5                                                                                        [b, mag_b, gravity_disturbance]
# 6                                                                              [b, mag_b, heatflux, gravity_disturbance]
# 7                                                                                                                 [s, h]
# 8                                                                                                         [mag_h, mag_s]
# 9                                                                                        [heatflux, gravity_disturbance]
# 10                                                                                [s, h, mag_h, mag_s, surface_air_temp]
# 11                                                                                                  [s, h, mag_h, mag_s]
# 12                                                                 [driving_stress, snow_accumulation, surface_air_temp]

# %%
df_pig = process_csv('regularized_const_01C_C_only_englacial_temp_pig_r005_geo_12.csv')
df_thwaites = process_csv('regularized_const_01C_C_only_englacial_temp_thwaites_r005_geo_12.csv')
df_dotson = process_csv('regularized_const_01C_C_only_englacial_temp_dotson_r005_geo_12.csv')

# %%
df_thwaites['C'].min(), df_thwaites['C'].max(), df_thwaites['theta'].min(), df_thwaites['theta'].max()

# %%
df_dotson['C'].min(), df_dotson['C'].max(), df_dotson['theta'].min(), df_dotson['theta'].max()

# %%
df_pig['C'].min(), df_pig['C'].max(), df_pig['theta'].min(), df_pig['theta'].max()
