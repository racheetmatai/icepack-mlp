# %%
from mlp_ensemble import loop_train_ensemble_mlp_model, train_ensemble_mlp_model, load_ensemble_mlp_model
# Out:
# 2024-12-21 00:43:17.488160: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-21 00:43:17.507846: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-21 00:43:17.513929: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-21 00:43:17.528659: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# import pickle
# import os
# base_folder = os.path.join('mlp_ensemble', '4628765226947308793', 'model_4_dotson2_thwaites1_r1_geo_mixed_C_0.pkl')
# with open(base_folder, "rb") as f:
#     model_bundle = pickle.load(f)

# %%
# model_bundle['input_columns']

# %%
input_columns = ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'mag_anomaly', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance']
#static_columns =   #['b', 'mag_b','mag_anomaly', 'heatflux'] static 4 models # ['b', 'mag_b', 'heatflux'] static_3 models: only got 1 model with R2> 0.2 # ['b', 'mag_b', 'mag_anomaly'] and ['b', 'mag_b']  and ['mag_anomaly', 'heatflux'] have r2 < 0.2
#dynamic_columns =  # ['s',  'h', 'mag_h', 'mag_s'] dynamic 4 models #['s',  'h', 'mag_h', 'mag_s', 'driving_stress'] dynamic 5 models # ['h',  'mag_h'] and ['s',  'mag_s'] have r2 < 0.2 
column_list = [
    ###['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'mag_anomaly', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance'], ## #all columns
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance'], #
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress', 'snow_accumulation', 'surface_air_temp'], # # dynamic columns 
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress'], 
    ['s',  'h', 'mag_h', 'mag_s', 'snow_accumulation'], 
    ['s',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], 
    ['s',  'h', 'mag_h', 'mag_s'], 
    ['mag_h', 'mag_s'], #
    ['s',  'h'], #
    ['driving_stress', 'snow_accumulation', 'surface_air_temp'], #
    # #['b', 'mag_b','mag_anomaly', 'heatflux', 'gravity_disturbance'],  ## # static columns
    # #['b', 'mag_b','mag_anomaly','gravity_disturbance'], ##
    # #['b', 'mag_b','mag_anomaly'],
    ['b', 'mag_b','gravity_disturbance'], #
    ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], 
    ['b', 'mag_b','heatflux'], 
    ['heatflux', 'gravity_disturbance'], 
    ['s',  'h', 'mag_h', 'mag_s', 'surface_air_temp', 'heatflux', 'gravity_disturbance']
]
number_of_models = 10
epochs = 700

# %%
model_list, input_scaler_list, output_scaler_list, history_list, r2_stats_list, r2_adjusted_stats_list, mse_stats_list, df_summary = loop_train_ensemble_mlp_model(column_list , epochs = epochs, variable = 'C', number_of_models = number_of_models, bad_r2_score = -500, start_number = 0, variable_type = 'mixed', select_dataset = 0, base_folder_name = 'mlp_ensemble_englacial')
#model_list, input_scaler, output_scaler, history_list = train_ensemble_mlp_model(epochs = 500, variable = 'C', number_of_models = number_of_models, columns = static_columns, bad_r2_score = 0.2, start_number = 0, variable_type = 'static')
# Out:
# dataset selected: [df_dotson (weight=2), df_thwaites (weight=1)]
# /srv/conda/envs/notebook/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-12-21 00:43:33.334640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Epoch 1/700
# 2024-12-21 00:43:41.342545: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-21 00:43:41.987589: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90300
#   68/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 0.3057
# 2024-12-21 00:43:43.527439: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 64 bytes spill stores, 64 bytes spill loads
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126
# 2024-12-21 00:43:58.705925: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_12', 64 bytes spill stores, 64 bytes spill loads
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step - loss: 0.0126 - val_loss: 5.9785e-04 - learning_rate: 0.0010
# Epoch 2/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 4.7322e-04 - val_loss: 3.1837e-04 - learning_rate: 0.0010
# Epoch 3/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 3.4692e-04 - val_loss: 2.2117e-04 - learning_rate: 0.0010
# Epoch 4/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 2.8245e-04 - val_loss: 3.7780e-04 - learning_rate: 0.0010
# Epoch 5/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 2.4214e-04 - val_loss: 3.5262e-04 - learning_rate: 0.0010
# Epoch 6/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 2.0132e-04 - val_loss: 3.6154e-04 - learning_rate: 0.0010
# Epoch 7/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.9961e-04 - val_loss: 1.3849e-04 - learning_rate: 0.0010
# Epoch 8/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.7233e-04 - val_loss: 1.4065e-04 - learning_rate: 0.0010
# Epoch 9/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 1.4477e-04 - val_loss: 1.6198e-04 - learning_rate: 0.0010
# Epoch 10/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 2.1337e-04 - val_loss: 2.5581e-04 - learning_rate: 0.0010
# Epoch 11/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.3961e-04 - val_loss: 4.3025e-04 - learning_rate: 0.0010
# Epoch 12/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.3367e-04 - val_loss: 6.1788e-04 - learning_rate: 0.0010
# Epoch 13/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 2.8055e-04 - val_loss: 9.3618e-05 - learning_rate: 0.0010
# Epoch 14/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.0854e-04 - val_loss: 3.2784e-04 - learning_rate: 0.0010
# Epoch 15/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.0662e-04 - val_loss: 2.2749e-04 - learning_rate: 0.0010
# Epoch 16/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.0786e-04 - val_loss: 1.9203e-04 - learning_rate: 0.0010
# Epoch 17/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 9.1721e-05 - val_loss: 5.4113e-04 - learning_rate: 0.0010
# Epoch 18/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.9976e-05 - val_loss: 1.4171e-04 - learning_rate: 0.0010
# Epoch 19/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 9.1594e-05 - val_loss: 8.1954e-04 - learning_rate: 0.0010
# Epoch 20/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.1652e-04 - val_loss: 1.4248e-04 - learning_rate: 0.0010
# Epoch 21/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.0660e-04 - val_loss: 3.1154e-04 - learning_rate: 0.0010
# Epoch 22/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.2781e-04 - val_loss: 1.1762e-04 - learning_rate: 0.0010
# Epoch 23/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.1700e-04 - val_loss: 2.1118e-04 - learning_rate: 0.0010
# Epoch 24/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.1543e-04 - val_loss: 1.0304e-04 - learning_rate: 0.0010
# Epoch 25/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.8929e-04 - val_loss: 2.4431e-04 - learning_rate: 0.0010
# Epoch 26/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.0726e-04 - val_loss: 8.7611e-04 - learning_rate: 0.0010
# Epoch 27/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.9742e-05 - val_loss: 3.5696e-04 - learning_rate: 0.0010
# Epoch 28/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.3209e-05 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 29/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.1502e-05 - val_loss: 9.7544e-05 - learning_rate: 0.0010
# Epoch 30/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 6.9611e-05 - val_loss: 1.1163e-04 - learning_rate: 0.0010
# Epoch 31/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.8955e-05 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 32/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.6807e-05 - val_loss: 0.1135 - learning_rate: 0.0010
# Epoch 33/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.1061e-04 - val_loss: 1.1962e-04 - learning_rate: 0.0010
# Epoch 34/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.8774e-05 - val_loss: 4.1593e-04 - learning_rate: 0.0010
# Epoch 35/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.7218e-05 - val_loss: 1.6185e-04 - learning_rate: 0.0010
# Epoch 36/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 9.0417e-05 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 37/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 2.0511e-04 - val_loss: 2.6409e-04 - learning_rate: 0.0010
# Epoch 38/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.2627e-04 - val_loss: 1.1439e-04 - learning_rate: 0.0010
# Epoch 39/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.0008e-05 - val_loss: 2.5501e-04 - learning_rate: 0.0010
# Epoch 40/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.2361e-04 - val_loss: 9.8881e-05 - learning_rate: 0.0010
# Epoch 41/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.8071e-05 - val_loss: 1.1520e-04 - learning_rate: 0.0010
# Epoch 42/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.1866e-04 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 43/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.2266e-04 - val_loss: 4.1896e-04 - learning_rate: 0.0010
# Epoch 44/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.2472e-04 - val_loss: 1.2524e-04 - learning_rate: 0.0010
# Epoch 45/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.8920e-05 - val_loss: 1.1195e-04 - learning_rate: 0.0010
# Epoch 46/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.6447e-05 - val_loss: 9.2019e-05 - learning_rate: 0.0010
# Epoch 47/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.5380e-05 - val_loss: 5.3537e-05 - learning_rate: 0.0010
# Epoch 48/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.3446e-05 - val_loss: 1.0225e-04 - learning_rate: 0.0010
# Epoch 49/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.7999e-05 - val_loss: 5.5522e-05 - learning_rate: 0.0010
# Epoch 50/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.6739e-05 - val_loss: 5.8082e-05 - learning_rate: 0.0010
# Epoch 51/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.4696e-05 - val_loss: 4.1657e-05 - learning_rate: 0.0010
# Epoch 52/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 5.3845e-05 - val_loss: 4.7934e-05 - learning_rate: 0.0010
# Epoch 53/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.6084e-05 - val_loss: 5.1737e-05 - learning_rate: 0.0010
# Epoch 54/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.2580e-05 - val_loss: 4.5804e-05 - learning_rate: 0.0010
# Epoch 55/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.1321e-05 - val_loss: 2.0125e-04 - learning_rate: 0.0010
# Epoch 56/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.7202e-05 - val_loss: 7.0316e-05 - learning_rate: 0.0010
# Epoch 57/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.3290e-05 - val_loss: 4.0390e-05 - learning_rate: 0.0010
# Epoch 58/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 9.4928e-05 - val_loss: 4.2888e-05 - learning_rate: 0.0010
# Epoch 59/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.7320e-05 - val_loss: 5.0240e-05 - learning_rate: 0.0010
# Epoch 60/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.2947e-05 - val_loss: 4.7371e-05 - learning_rate: 0.0010
# Epoch 61/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.8038e-05 - val_loss: 1.2095e-04 - learning_rate: 0.0010
# Epoch 62/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.5604e-05 - val_loss: 7.0970e-05 - learning_rate: 0.0010
# Epoch 63/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.4088e-05 - val_loss: 7.7802e-05 - learning_rate: 0.0010
# Epoch 64/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.0489e-05 - val_loss: 4.0659e-05 - learning_rate: 0.0010
# Epoch 65/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.0079e-05 - val_loss: 1.9556e-04 - learning_rate: 0.0010
# Epoch 66/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.1403e-05 - val_loss: 5.2566e-05 - learning_rate: 0.0010
# Epoch 67/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.0407e-05 - val_loss: 5.6779e-05 - learning_rate: 0.0010
# Epoch 68/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.2028e-05 - val_loss: 4.7037e-05 - learning_rate: 0.0010
# Epoch 69/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.1994e-04 - val_loss: 5.1384e-05 - learning_rate: 0.0010
# Epoch 70/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.1592e-05 - val_loss: 6.7803e-04 - learning_rate: 0.0010
# Epoch 71/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.3473e-04 - val_loss: 4.7460e-05 - learning_rate: 0.0010
# Epoch 72/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.2227e-05 - val_loss: 3.1691e-05 - learning_rate: 0.0010
# Epoch 73/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.9797e-05 - val_loss: 7.1143e-05 - learning_rate: 0.0010
# Epoch 74/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.5601e-05 - val_loss: 4.5219e-05 - learning_rate: 0.0010
# Epoch 75/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.2924e-05 - val_loss: 1.2610e-04 - learning_rate: 0.0010
# Epoch 76/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.8164e-05 - val_loss: 6.5728e-05 - learning_rate: 0.0010
# Epoch 77/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.8728e-05 - val_loss: 3.7567e-05 - learning_rate: 0.0010
# Epoch 78/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.0207e-05 - val_loss: 1.3090e-04 - learning_rate: 0.0010
# Epoch 79/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.2054e-05 - val_loss: 1.7921e-04 - learning_rate: 0.0010
# Epoch 80/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.6035e-05 - val_loss: 1.0138e-04 - learning_rate: 0.0010
# Epoch 81/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.1363e-05 - val_loss: 1.0676e-04 - learning_rate: 0.0010
# Epoch 82/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.4404e-05 - val_loss: 6.4199e-05 - learning_rate: 0.0010
# Epoch 83/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.3819e-05 - val_loss: 4.7680e-05 - learning_rate: 0.0010
# Epoch 84/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.1845e-05 - val_loss: 1.5083e-04 - learning_rate: 0.0010
# Epoch 85/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.4638e-05 - val_loss: 5.1541e-05 - learning_rate: 0.0010
# Epoch 86/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.4266e-05 - val_loss: 5.8232e-04 - learning_rate: 0.0010
# Epoch 87/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.1908e-05 - val_loss: 2.4560e-04 - learning_rate: 0.0010
# Epoch 88/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.3194e-05 - val_loss: 4.7828e-05 - learning_rate: 0.0010
# Epoch 89/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.9554e-05 - val_loss: 6.1172e-05 - learning_rate: 0.0010
# Epoch 90/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 9.2855e-05 - val_loss: 4.1039e-05 - learning_rate: 0.0010
# Epoch 91/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.5328e-05 - val_loss: 4.7490e-05 - learning_rate: 0.0010
# Epoch 92/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.0458e-05 - val_loss: 5.7985e-05 - learning_rate: 0.0010
# Epoch 93/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.8912e-05 - val_loss: 2.8410e-05 - learning_rate: 0.0010
# Epoch 94/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.5117e-05 - val_loss: 3.1317e-05 - learning_rate: 0.0010
# Epoch 95/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.5111e-05 - val_loss: 4.7930e-05 - learning_rate: 0.0010
# Epoch 96/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.7994e-05 - val_loss: 1.1978e-04 - learning_rate: 0.0010
# Epoch 97/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.9039e-05 - val_loss: 3.2973e-05 - learning_rate: 0.0010
# Epoch 98/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.0981e-05 - val_loss: 2.5431e-05 - learning_rate: 0.0010
# Epoch 99/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.7791e-05 - val_loss: 4.0828e-05 - learning_rate: 0.0010
# Epoch 100/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.9052e-05 - val_loss: 4.6557e-05 - learning_rate: 0.0010
# Epoch 101/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.8151e-05 - val_loss: 1.4518e-04 - learning_rate: 0.0010
# Epoch 102/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.4011e-05 - val_loss: 3.5498e-05 - learning_rate: 0.0010
# Epoch 103/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.1181e-05 - val_loss: 3.6963e-05 - learning_rate: 0.0010
# Epoch 104/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.3683e-05 - val_loss: 4.7194e-05 - learning_rate: 0.0010
# Epoch 105/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.0035e-05 - val_loss: 3.6715e-05 - learning_rate: 0.0010
# Epoch 106/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.6635e-05 - val_loss: 8.0913e-05 - learning_rate: 0.0010
# Epoch 107/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.5790e-05 - val_loss: 3.6386e-05 - learning_rate: 0.0010
# Epoch 108/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 3.9593e-05 - val_loss: 1.2881e-04 - learning_rate: 0.0010
# Epoch 109/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.1051e-05 - val_loss: 1.1077e-04 - learning_rate: 0.0010
# Epoch 110/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 8.1343e-05 - val_loss: 6.4153e-05 - learning_rate: 0.0010
# Epoch 111/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 9.8157e-05 - val_loss: 5.0638e-05 - learning_rate: 0.0010
# Epoch 112/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 1.4795e-04 - val_loss: 3.6701e-05 - learning_rate: 0.0010
# Epoch 113/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.9020e-05 - val_loss: 8.0492e-05 - learning_rate: 0.0010
# Epoch 114/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.3181e-05 - val_loss: 4.1198e-05 - learning_rate: 0.0010
# Epoch 115/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.2295e-05 - val_loss: 4.2272e-05 - learning_rate: 0.0010
# Epoch 116/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.6115e-05 - val_loss: 5.2202e-05 - learning_rate: 0.0010
# Epoch 117/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.9017e-05 - val_loss: 7.6977e-05 - learning_rate: 0.0010
# Epoch 118/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 6.1862e-05 - val_loss: 4.1847e-05 - learning_rate: 0.0010
# Epoch 119/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.9675e-05 - val_loss: 1.3740e-04 - learning_rate: 0.0010
# Epoch 120/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.5844e-05 - val_loss: 5.2820e-05 - learning_rate: 0.0010
# Epoch 121/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.5042e-05 - val_loss: 4.4531e-05 - learning_rate: 0.0010
# Epoch 122/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.6524e-05 - val_loss: 5.2124e-05 - learning_rate: 0.0010
# Epoch 123/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 5.1636e-05 - val_loss: 6.0611e-05 - learning_rate: 0.0010
# Epoch 124/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.5269e-05 - val_loss: 5.3542e-05 - learning_rate: 0.0010
# Epoch 125/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.5386e-05 - val_loss: 3.6517e-05 - learning_rate: 0.0010
# Epoch 126/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 3.8969e-05 - val_loss: 2.7145e-05 - learning_rate: 0.0010
# Epoch 127/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 3.5339e-05 - val_loss: 6.0242e-05 - learning_rate: 0.0010
# Epoch 128/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.3249e-05 - val_loss: 2.5629e-05 - learning_rate: 0.0010
# Epoch 129/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.0887e-05 - val_loss: 1.1363e-04 - learning_rate: 0.0010
# Epoch 130/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 7.2140e-05 - val_loss: 2.4713e-05 - learning_rate: 0.0010
# Epoch 131/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 3.8593e-05 - val_loss: 3.4292e-05 - learning_rate: 0.0010
# Epoch 132/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 3.6382e-05 - val_loss: 2.5397e-05 - learning_rate: 0.0010
# Epoch 133/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 3.6011e-05 - val_loss: 1.9171e-05 - learning_rate: 0.0010
# Epoch 134/700
# 6161/6161 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 4.0273e-05 - val_loss: 3.2191e-05 - learning_rate: 0.0010
# Epoch 135/700
# 5848/6161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9114e-05

# %%
df_summary

# %%
#model_list, input_scaler, output_scaler, input_columns, variable = load_ensemble_mlp_model(input_columns, number_of_models = len(model_list), variable = 'C')
