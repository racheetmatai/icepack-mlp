# %%
from mlp_ensemble import loop_train_ensemble_mlp_model, train_ensemble_mlp_model, load_ensemble_mlp_model
# Out:
# 2024-12-21 01:14:16.667270: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-21 01:14:16.686695: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-21 01:14:16.692728: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-21 01:14:16.708330: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# import pickle
# import os
# base_folder = os.path.join('mlp_ensemble', '4628765226947308793', 'model_4_dotson2_thwaites1_r1_geo_mixed_C_0.pkl')
# with open(base_folder, "rb") as f:
#     model_bundle = pickle.load(f)

# %%
# model_bundle['input_columns']

# %%
input_columns = ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'mag_anomaly', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance']
#static_columns =   #['b', 'mag_b','mag_anomaly', 'heatflux'] static 4 models # ['b', 'mag_b', 'heatflux'] static_3 models: only got 1 model with R2> 0.2 # ['b', 'mag_b', 'mag_anomaly'] and ['b', 'mag_b']  and ['mag_anomaly', 'heatflux'] have r2 < 0.2
#dynamic_columns =  # ['s',  'h', 'mag_h', 'mag_s'] dynamic 4 models #['s',  'h', 'mag_h', 'mag_s', 'driving_stress'] dynamic 5 models # ['h',  'mag_h'] and ['s',  'mag_s'] have r2 < 0.2 
column_list = [
    #['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'mag_anomaly', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance'], ## #all columns
    ['s', 'b', 'h', 'mag_h', 'mag_s', 'mag_b', 'driving_stress', 'heatflux', 'snow_accumulation', 'surface_air_temp','gravity_disturbance'], ##
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress', 'snow_accumulation', 'surface_air_temp'], ## # dynamic columns
    ['s',  'h', 'mag_h', 'mag_s', 'driving_stress'], ##
    ['s',  'h', 'mag_h', 'mag_s', 'snow_accumulation'], ##
    ['s',  'h', 'mag_h', 'mag_s', 'surface_air_temp'], ##
    ['s',  'h', 'mag_h', 'mag_s'], ##
    ['mag_h', 'mag_s'], ##
    ['s',  'h'], ##
    ['driving_stress', 'snow_accumulation', 'surface_air_temp'], ##
    #['b', 'mag_b','mag_anomaly', 'heatflux', 'gravity_disturbance'],  ## # static columns
    #['b', 'mag_b','mag_anomaly','gravity_disturbance'], ##
    #['b', 'mag_b','mag_anomaly'],
    ['b', 'mag_b','gravity_disturbance'], ##
    ['b', 'mag_b', 'heatflux', 'gravity_disturbance'], ##
    ['b', 'mag_b','heatflux'], ##
    ['heatflux', 'gravity_disturbance'], ##
    ['s',  'h', 'mag_h', 'mag_s', 'surface_air_temp', 'heatflux', 'gravity_disturbance']
]
number_of_models = 10
epochs = 700

# %%
model_list, input_scaler_list, output_scaler_list, history_list, r2_stats_list, r2_adjusted_stats_list, mse_stats_list, df_summary = loop_train_ensemble_mlp_model(column_list, epochs = epochs, variable = 'C', number_of_models = number_of_models, bad_r2_score = -500, start_number = 0, variable_type = 'mixed', select_dataset = 3, base_folder_name = 'mlp_ensemble_englacial')
#model_list, input_scaler, output_scaler, history_list = train_ensemble_mlp_model(epochs = 500, variable = 'C', number_of_models = number_of_models, columns = static_columns, bad_r2_score = 0.2, start_number = 0, variable_type = 'static')
# Out:
# dataset selected: [df_dotson (weight=1)]
# /srv/conda/envs/notebook/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-12-21 01:14:32.718587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Epoch 1/700
# 2024-12-21 01:14:40.654866: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-21 01:14:41.303022: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90300
#  70/883 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2342
# 2024-12-21 01:14:42.817232: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 64 bytes spill stores, 64 bytes spill loads
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0401
# 2024-12-21 01:14:46.742774: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 64 bytes spill stores, 64 bytes spill loads
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 0.0401 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 2/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 8.8357e-04 - val_loss: 5.0983e-04 - learning_rate: 0.0010
# Epoch 3/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.8906e-04 - val_loss: 4.7608e-04 - learning_rate: 0.0010
# Epoch 4/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.4900e-04 - val_loss: 6.8381e-04 - learning_rate: 0.0010
# Epoch 5/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.7238e-04 - val_loss: 3.8419e-04 - learning_rate: 0.0010
# Epoch 6/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.2066e-04 - val_loss: 2.7631e-04 - learning_rate: 0.0010
# Epoch 7/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2639e-04 - val_loss: 2.4602e-04 - learning_rate: 0.0010
# Epoch 8/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.4915e-04 - val_loss: 5.5302e-04 - learning_rate: 0.0010
# Epoch 9/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1595e-04 - val_loss: 3.2711e-04 - learning_rate: 0.0010
# Epoch 10/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 3.0500e-04 - val_loss: 7.3896e-04 - learning_rate: 0.0010
# Epoch 11/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.7093e-04 - val_loss: 4.4619e-04 - learning_rate: 0.0010
# Epoch 12/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.9582e-04 - val_loss: 5.1160e-04 - learning_rate: 0.0010
# Epoch 13/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1017e-04 - val_loss: 2.7387e-04 - learning_rate: 0.0010
# Epoch 14/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.4829e-04 - val_loss: 2.0421e-04 - learning_rate: 0.0010
# Epoch 15/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.4494e-04 - val_loss: 2.8358e-04 - learning_rate: 0.0010
# Epoch 16/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.5121e-04 - val_loss: 7.5339e-04 - learning_rate: 0.0010
# Epoch 17/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.1971e-04 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 18/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.3570e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 19/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.8455e-04 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 20/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.4857e-04 - val_loss: 3.7481e-04 - learning_rate: 0.0010
# Epoch 21/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.9025e-04 - val_loss: 2.9909e-04 - learning_rate: 0.0010
# Epoch 22/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.9870e-04 - val_loss: 2.2850e-04 - learning_rate: 0.0010
# Epoch 23/700
# 883/883 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7785e-04 - val_loss: 7.3068e-04 - learning_rate: 0.0010
# Epoch 24/700
# 388/883 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7695e-04

# %%
df_summary

# %%
#model_list, input_scaler, output_scaler, input_columns, variable = load_ensemble_mlp_model(input_columns, number_of_models = len(model_list), variable = 'C')
